# %% [markdown]
# #Python cơ bản
#
# ######Ngày 2
# ---

# %% [markdown]
# ##Tóm tắt buổi 2
# Lưu ý thụt đầu dòng, nếu dùng tab thì cả script phải dùng tab, còn dấu cách thì cả script phải dùng cách.
#
#
# ###Câu lệnh `if`
# Cú pháp:
#
# ```python
#
# if điều kiện:
#   code cần chạy
# #Không bắt buộc
# elif điều kiện 2: # nếu điều kiện 1 sai -> kiểm tra điều kiện 2
#   code sẽ chạy nếu điều kiện 2 đúng và điều kiện 1 sai
# else:
#    code sẽ chạy nếu cả 1 và 2 đều sai
# ```
#
# ###Array
#
# Array là mảng để chứa một dãy các dữ liệu
#
# Cú pháp:
#
# ```python
# #Tạo array đặt tên là arr chứa 3 số 1,2 và 3
# arr = [1,2,3]
# #Lấy giá trị từ arr
# x = arr[0]
# #thì x = 1 ( truy cập các phần tử của arr từ 0 đến 2 (3 phần tử) )
#
# #array có thể chứa nhiều kiểu dữ liệu khác nhau
# arr2 = [1,'a',True]
# ```
#
# ###Tuple
#
# Tuple giống array nhưng không thay đổi được giá trị trong nó
#
# Cú pháp:
#
# ```python
# tup = (1,2,3)
#
# x = tup[0]
# #x = 1
#
# ```
#
#
# ###Dictionary
# Dictionary lưu dữ liệu theo từng key
#
# Cú pháp:
#
# ```python
# d = {'a' :100,'b' : 200}
#
# x =  d['a']
# #x = 100
#
# ```
#
# ###Vòng lặp `for`
# Lặp qua các phần tử của mảng,Tuple hoặc keys của dictionary
#
# Cú pháp:
#
# ```python
# for phần tử in mảng:
#   ...
#
# #Ví dụ
# arr = [1,2,3,4,5,6,7,8]
# for i in arr:
#   print(i)
#   # in từ 1 -> 8
# ```
# ###Vòng lặp `while`
# Lặp trong khi điều kiện thoản mãn
#
# Cú pháp:
#
# ```python
# while điều kiện:
#   ...
#
# #Ví dụ
# i = 0
# while i < 10:
#   i+= 1
#   print(i)
#   # in từ 1 -> 10
# ```

# %% [markdown]
# -----
# ##**Bài tập về nhà 📔**

# %% [markdown]
# ####Bài 1
# Viết chương trình giải phương trình bậc hai, Trả lại 2 biến x1, x2 với điều kiện:
#
#
# *   Nếu phương trình (pt) có 2 nghiệm trả lại x1 và x2
# *   Nếu pt có 1 nghiệm trả lại x1 = x2
# *   Nếu pt vô nghiệm trả lại x1 = x2 = `None`
#
# (Căn bậc 2 dùng hàm `sqrt(x)`, Lưu ý: không thay đổi giá trị a,b,c)
#
# Ví dụ:
#
# ```python
# #Căn bậc 2 của x:
# x = 3
# can_bac_2_cua_X = sqrt(x)
#
# ```

# %%
'''

delta = ...
if delta > 0:
  ..
'''
from math import sqrt
a = 2
b = 6
c = 2
#(≈ 10 - 14 dòng code)
# BẮT ĐẦU CODE
x1 = None
X2 = None
delta = b** 2 -(4*a*c)
if delta > 0:
  x1 = (-b+ sqrt(delta))/(2*a)
  x2 = (-b- sqrt(delta))/(2*a)
elif delta == 0:
  x1 = -b/(2*a)
  x2 = x1
else:
  x1 = None
  x2 = None


# KẾT THÚC CODE

#In ra kết quả
if x1 == x2 and x1 != None:
  print("Phuong trinh co 1 nghiem")
elif x1 == None and x2 == None:
  print("Phuong trinh vo nghiem")
else:
  print(f"Phuong trinh co 2 nghiem {x1} va {x2}")

# %% [markdown]
# ####Bài 2
# Lặp qua mảng arr cho sẵn, tìm số lớn nhất trong mảng

# %%
'''
max = 0
for i in arr:
  if i ...
'''

arr = [1,2,5,7,8,3,2,1]
#(≈ 4 dòng code)
# BẮT ĐẦU CODE
# For - While
'''
max = arr[0]
for a in arr:
  if a > max:
    max = a
'''


max = arr[0]
i = 0
while i < len(arr):
  if arr[i] > max:
    max = arr[i]
  i += 1
# KẾT THÚC CODE
print(f"Số lớn nhất trong mảng là {max}")

# %% [markdown]
# ####Bài 3
# Viết chương trình lặp tính tổng từ số nhập vào từ người dùng, lặp cho đến khi tổng các số nhập vào lớn hơn 100
#
# Ví dụ:
# người dùng nhập 10 -> lặp tiếp
#
# người dùng nhập 20 -> Tổng là 30 < 100 ,lặp tiếp
#
# người dùng nhập 100 -> Tổng là 130 > 100 dừng lặp

# %%
'''
sum = ..
while sum...

'''

#(≈ 4 dòng code)
# BẮT ĐẦU CODE
sum = 0
while sum < 100:
  sum = sum+int(input())


# KẾT THÚC CODE
print(f"Tổng các số nhập vào là {sum}")

# %% [markdown]
# #Tạo file kết quả
# Sau khi bạn làm xong tất cả bài tập bên trên hãy sửa biến MSSV dưới đây từ 2xxxxxxx thành mã số sinh viên của bạn; ví dụ:
# `MSSV = "21010294"`
# , sau đó chạy đoạn code để tạo file kết quả.
#
# Kết quả của bạn sẽ được lưu thành file có tên là mã sinh viên của bạn, sau đó bạn bấm vào Files > chọn file của bạn > Download để tải file kết quả bài làm về máy.
#
# ![image.png](data:image/png;base64,...)

# %%
import pickle
# BẮT ĐẦU CODE
MSSV = "2xxxxxxx"
# KẾT THÚC CODE
get_list = ['x1','x2','max','sum']
glb_vars = vars()
with open(str(MSSV)+'.kq2', 'wb') as handle:
    g = dict()
    for i in glb_vars:
      if i in get_list:
        g[i] = glb_vars[i]
    pickle.dump(g, handle, protocol=pickle.HIGHEST_PROTOCOL)
    handle.close()
